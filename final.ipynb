# %%
# !pip install lxml

# %%
import pandas as pd

# %% [markdown]
# ## Откроем таблицу инфляции прямо с сайта!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
url = 'https://xn----ctbjnaatncev9av3a8f8b.xn--p1ai/%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D1%8B-%D0%B8%D0%BD%D1%84%D0%BB%D1%8F%D1%86%D0%B8%D0%B8'
df_infl = pd.read_html(url, index_col='Год', )[0]

df_infl.head()
# Out:
#         Янв    Фев    Мар    Апр    Май    Июн    Июл    Авг    Сен    Окт  \
# Год
# 2024   7.44   7.67    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2023  11.76  10.97   3.51   2.30   2.50   3.24   4.30   5.13   6.00   6.68
# 2022   8.74   9.16  16.70  17.83  17.11  15.90  15.09  14.30  13.67  12.63
# 2021   5.19   5.67   5.78   5.52   6.01   6.51   6.47   6.69   7.41   8.14
# 2020   2.42   2.31   2.55   3.10   3.03   3.21   3.37   3.57   3.67   3.98
#
#         Ноя    Дек  Всего
# Год
# 2024    NaN    NaN   1.55
# 2023   7.47   7.42   7.42
# 2022  11.97  11.92  11.92
# 2021   8.40   8.39   8.39
# 2020   4.42   4.91   4.91

# %%
url = 'https://rosstat.gov.ru/storage/mediabank/tab3-zpl_2023.xlsx'

df =df=pd.read_excel(url, sheet_name='с 2017 г.')

df.head()
# Out:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  СРЕДНЕМЕСЯЧНАЯ НОМИНАЛЬНАЯ НАЧИСЛЕННАЯ ЗАРАБОТ...        NaN         NaN
# 1  ОРГАНИЗАЦИЙ ПО ВИДАМ ЭКОНОМИЧЕСКОЙ ДЕЯТЕЛЬНОСТ...        NaN         NaN
# 2                                                NaN        NaN         NaN
# 3                                                NaN     20171)      2018.0
# 4                                              Всего      39167     43724.0
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN
# 3      2019.0      2020.0      2021.0     20222)  20232), 3)
# 4     47866.8     51344.0     57243.7    65338.3     73709.3

# %% [markdown]
# ## Выделяем годовую инфляцию за необходимый период

# %%
infl = df_infl.loc[df_infl.index >= 2000 , 'Всего'][1:]

infl
# Out:
# Год
# 2023     7.42
# 2022    11.92
# 2021     8.39
# 2020     4.91
# 2019     3.05
# 2018     4.27
# 2017     2.52
# 2016     5.38
# 2015    12.91
# 2014    11.36
# 2013     6.45
# 2012     6.58
# 2011     6.10
# 2010     8.78
# 2009     8.80
# 2008    13.28
# 2007    11.87
# 2006     9.00
# 2005    10.91
# 2004    11.74
# 2003    11.99
# 2002    15.06
# 2001    18.58
# 2000    20.20
# Name: Всего, dtype: float64

# %%
pd.DataFrame(df_infl)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a00b400060a4> in <module>
# ----> 1 pd.DataFrame(df_infl)
#
# d:\gb\ds\env\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     796                     )
#     797                 else:
# --> 798                     mgr = ndarray_to_mgr(
#     799                         data,
#     800                         index,
#
# d:\gb\ds\env\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     318         # by definition an array here
#     319         # the dtypes will be coerced to a single dtype
# --> 320         values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     321
#     322     if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#
# ...
